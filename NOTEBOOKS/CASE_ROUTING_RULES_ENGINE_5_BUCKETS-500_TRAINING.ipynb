# %%
#all the imports used in the program

import pandas as pd 
import pyodbc
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.metrics import categorical_accuracy
from keras.models import Sequential
from keras.layers import Embedding, Flatten, Dense, Bidirectional, LSTM
from keras.layers import GlobalMaxPool1D, Conv1D, Dropout, GRU, Flatten, MaxPooling1D
from sklearn.metrics import f1_score, confusion_matrix, classification_report
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
import sklearn.metrics as skm
# Out:
# Using TensorFlow backend.

# %%
#Grab data from a database

def getData(Server, UID, PWD, Database, query):    
    
    #create a SQL connection based on the given server and database
    sql_conn = pyodbc.connect('DRIVER={SQL Server};'
                              'SERVER='+Server+';' 
                              'UID='+UID+';'
                              'PWD='+PWD+';'
                              'DATABASE='+Database+';' )
    
    #return the data from the given Query and SQL connection,
    return pd.read_sql(query, sql_conn)

# %%
#establish my server and corresponding database to pull data from
server ='GSDEMO2HOST'
database = 'MClinical'
UID = 'gsanalytics'
PWD = 'G3st@lt'


#Stores the result in a pandas DataFrame object called data
query ="SELECT ISNULL(ProcedureStep.subSpecialtyCd,'UNKNOWN') AS subSpecialtyCd, FillerOrder.fillerOrderStatusCd, PL.locationName, BUCKETS.BUCKETNUM FROM BUCKETS LEFT JOIN ProcedureStep ON BUCKETS.PSKEY = ProcedureSteP.procedureStepKey LEFT JOIN RequestedProcedure ON ProcedureStep.requestedProcedureKey = RequestedProcedure.requestedProcedureKey LEFT JOIN FillerOrder ON RequestedProcedure.fillerOrderKey = FillerOrder.fillerOrderKey LEFT JOIN LOCATION AS PL ON FillerOrder.scheduledLocationKey = PL.locationKey"
original = getData(server, UID, PWD, database,query)
data = original.copy()

# %%
#concatinate the selected params
def concatParam(df):
    return  df['subSpecialtyCd'] + ' ' + df['fillerOrderStatusCd'] + ' ' + df['locationName']

# %%
def clean(df):
    #create a new column where its all the params concatinated by spaces
    df['concat'] = concatParam(df)
    
    #change the case of all the words to lower case so there is no case sensitivity.
    df['concat'] = df['concat'].str.lower()
    return df['concat']

# %%
data['concat'] = clean(data)
data.concat.apply(lambda x: len(x.split(" "))).mean()
# Out:
# 5.0

# %%
def convert_text(df, maxlen, max_words):
    #split df into two series
    #texts being the concat
    #labels being the cooresponding bucket
    texts = df.concat
    labels = df.BUCKETNUM
    
    #convert the series into numpy arrays
    texts = texts.values
    temp_labels = labels.values
    
    #create a empty array for our labels that we will convert to integers
    labels = []
    
    #grab all the unique buckets (5) 
    #this will be our dictonary for mapping between integers and buckets
    label_dict = [1,2,3,4,5]
    label_dict = np.asarray(label_dict)

    
    for label_type in temp_labels:
        labels.append(np.searchsorted(label_dict, label_type))
    
    labels = np.asarray(labels)
    
    #create a tokenizer based on the max_words
    #fit the tokenizer to our specific texts
    #change our texts to a vetorized integer
    tokenizer = Tokenizer(num_words=max_words)
    tokenizer.fit_on_texts(texts)
    sequences = tokenizer.texts_to_sequences(texts)

    word_index = tokenizer.word_index
    print('Found %s unique tokens.' % len(word_index))
    
    #pad sequences ensures that all our vectors are of the same length
    x = pad_sequences(sequences, maxlen=maxlen)
    
    indices = np.arange(x.shape[0])
    np.random.shuffle(indices)
    x = x[indices]
    labels = labels[indices]

    print('Shape of data tensor:', x.shape)
    print('Shape of label tensor:', labels.shape)
    
    #return x, labels, and the last 7000 of x and labels for testing
    return x[:500], labels[:500], x[-9500:], labels[-9500:], indices

# %%
#define maxlen as the maximum words to take from each sectionValue
#define max_words as the total number of unique words to tokenize

maxlen = 8
max_words = 20

#create data that can be ran through our model
x_train, y_train, x_test, y_test, index = convert_text(data, maxlen, max_words)

data = data.reindex(index)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# Found 20 unique tokens.
# Shape of data tensor: (10000, 8)
# Shape of label tensor: (10000,)
# (500, 8)
# (500,)
# (9500, 8)
# (9500,)

# %%
#create a machine learning model with the following
def create_model(max_words,maxlen):
    #keras default model
    model = Sequential()
    
    #add an embedding layer with the input dim and input length to what we have already
    #configured for our vectorized forms of our text
    model.add(Embedding(input_dim = max_words, input_length=maxlen, output_dim = 50))
    
    #model.add(Embedding(max_words,50, input_length=maxlen, embeddings_initializer="uniform"))
    
    #add a bidirectional LSTM layer with 32 units
    model.add(Bidirectional(LSTM(units =32)))
    
    #model.add(Conv1D(maxlen, 1, padding='valid', activation='relu', strides=1))
    #model.add(GlobalMaxPool1D())
    
    # create a dense output layer with the units = len(labels_dict)
    model.add(Dense(5, activation='softmax'))
    
    #print the summary
    model.summary()
    
    return model

# %%
#create the model
model = create_model(max_words, maxlen)
# Out:
# WARNING:tensorflow:From C:\Users\csorensen\.conda\envs\test\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 8, 50)             1000
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 64)                21248
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 22,573
# Trainable params: 22,573
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train the model
def train_model(model, x_train, y_train, epochs, batchsize, max_words, max_len):
    #compile the model
    #optimizer -> rmsprop (standard)
    #loss -> sparse categorical crossentropy (because we have a large multiclassifcation probelm)
    #meteric -> accuracy
    model.compile(optimizer='rmsprop',
                  loss='sparse_categorical_crossentropy',
                  metrics=['acc']) 
    #save the history from the model
    #set the paramiters
    #fit the model 
    history = model.fit(x_train, 
                        y_train,
                        epochs=epochs,
                        batch_size=batchsize,
                        validation_split=0.05)
    return history

# %%
#train the model
history = train_model(model, x_train, y_train, 55, 80, max_words, maxlen)
# Out:
# WARNING:tensorflow:From C:\Users\csorensen\.conda\envs\test\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 475 samples, validate on 25 samples
# Epoch 1/55
# 475/475 [==============================] - 2s 4ms/step - loss: 1.5833 - acc: 0.4063 - val_loss: 1.5383 - val_acc: 0.3200
# Epoch 2/55
# 475/475 [==============================] - 0s 152us/step - loss: 1.5259 - acc: 0.4358 - val_loss: 1.4743 - val_acc: 0.5600
# Epoch 3/55
# 475/475 [==============================] - 0s 151us/step - loss: 1.4677 - acc: 0.5263 - val_loss: 1.4031 - val_acc: 0.3200
# Epoch 4/55
# 475/475 [==============================] - 0s 147us/step - loss: 1.4080 - acc: 0.3011 - val_loss: 1.3355 - val_acc: 0.5600
# Epoch 5/55
# 475/475 [==============================] - 0s 149us/step - loss: 1.3337 - acc: 0.5200 - val_loss: 1.2367 - val_acc: 0.5600
# Epoch 6/55
# 475/475 [==============================] - 0s 136us/step - loss: 1.2279 - acc: 0.5768 - val_loss: 1.0994 - val_acc: 0.3600
# Epoch 7/55
# 475/475 [==============================] - 0s 149us/step - loss: 1.0973 - acc: 0.6842 - val_loss: 0.9450 - val_acc: 0.7600
# Epoch 8/55
# 475/475 [==============================] - 0s 134us/step - loss: 0.9491 - acc: 0.7663 - val_loss: 0.7962 - val_acc: 0.7600
# Epoch 9/55
# 475/475 [==============================] - 0s 212us/step - loss: 0.8168 - acc: 0.7684 - val_loss: 0.6637 - val_acc: 0.7600
# Epoch 10/55
# 475/475 [==============================] - 0s 166us/step - loss: 0.6922 - acc: 0.8358 - val_loss: 0.5548 - val_acc: 0.9600
# Epoch 11/55
# 475/475 [==============================] - 0s 191us/step - loss: 0.5860 - acc: 0.9179 - val_loss: 0.4409 - val_acc: 0.9600
# Epoch 12/55
# 475/475 [==============================] - 0s 187us/step - loss: 0.4981 - acc: 0.9179 - val_loss: 0.3553 - val_acc: 0.9600
# Epoch 13/55
# 475/475 [==============================] - 0s 178us/step - loss: 0.4201 - acc: 0.9179 - val_loss: 0.2918 - val_acc: 0.9600
# Epoch 14/55
# 475/475 [==============================] - 0s 189us/step - loss: 0.3556 - acc: 0.9179 - val_loss: 0.2344 - val_acc: 0.9600
# Epoch 15/55
# 475/475 [==============================] - 0s 197us/step - loss: 0.3049 - acc: 0.9179 - val_loss: 0.2010 - val_acc: 0.9600
# Epoch 16/55
# 475/475 [==============================] - 0s 183us/step - loss: 0.2633 - acc: 0.9179 - val_loss: 0.1710 - val_acc: 0.9600
# Epoch 17/55
# 475/475 [==============================] - 0s 189us/step - loss: 0.2301 - acc: 0.9179 - val_loss: 0.1592 - val_acc: 0.9600
# Epoch 18/55
# 475/475 [==============================] - 0s 157us/step - loss: 0.2055 - acc: 0.9179 - val_loss: 0.1377 - val_acc: 0.9600
# Epoch 19/55
# 475/475 [==============================] - 0s 135us/step - loss: 0.1805 - acc: 0.9305 - val_loss: 0.1198 - val_acc: 0.9600
# Epoch 20/55
# 475/475 [==============================] - 0s 141us/step - loss: 0.1607 - acc: 0.9389 - val_loss: 0.0987 - val_acc: 0.9600
# Epoch 21/55
# 475/475 [==============================] - 0s 137us/step - loss: 0.1381 - acc: 0.9726 - val_loss: 0.0796 - val_acc: 0.9600
# Epoch 22/55
# 475/475 [==============================] - 0s 173us/step - loss: 0.1194 - acc: 0.9768 - val_loss: 0.0609 - val_acc: 1.0000
# Epoch 23/55
# 475/475 [==============================] - 0s 208us/step - loss: 0.1012 - acc: 0.9874 - val_loss: 0.0564 - val_acc: 1.0000
# Epoch 24/55
# 475/475 [==============================] - 0s 187us/step - loss: 0.0831 - acc: 0.9874 - val_loss: 0.0404 - val_acc: 1.0000
# Epoch 25/55
# 475/475 [==============================] - 0s 189us/step - loss: 0.0681 - acc: 0.9874 - val_loss: 0.0356 - val_acc: 1.0000
# Epoch 26/55
# 475/475 [==============================] - 0s 162us/step - loss: 0.0569 - acc: 0.9874 - val_loss: 0.0241 - val_acc: 1.0000
# Epoch 27/55
# 475/475 [==============================] - 0s 168us/step - loss: 0.0484 - acc: 0.9874 - val_loss: 0.0182 - val_acc: 1.0000
# Epoch 28/55
# 475/475 [==============================] - 0s 149us/step - loss: 0.0406 - acc: 0.9874 - val_loss: 0.0146 - val_acc: 1.0000
# Epoch 29/55
# 475/475 [==============================] - 0s 176us/step - loss: 0.0385 - acc: 0.9874 - val_loss: 0.0123 - val_acc: 1.0000
# Epoch 30/55
# 475/475 [==============================] - 0s 189us/step - loss: 0.0306 - acc: 0.9895 - val_loss: 0.0128 - val_acc: 1.0000
# Epoch 31/55
# 475/475 [==============================] - 0s 181us/step - loss: 0.0261 - acc: 0.9958 - val_loss: 0.0107 - val_acc: 1.0000
# Epoch 32/55
# 475/475 [==============================] - 0s 193us/step - loss: 0.0230 - acc: 0.9958 - val_loss: 0.0118 - val_acc: 1.0000
# Epoch 33/55
# 475/475 [==============================] - 0s 187us/step - loss: 0.0204 - acc: 0.9958 - val_loss: 0.0086 - val_acc: 1.0000
# Epoch 34/55
# 475/475 [==============================] - 0s 189us/step - loss: 0.0167 - acc: 0.9958 - val_loss: 0.0099 - val_acc: 1.0000
# Epoch 35/55
# 475/475 [==============================] - 0s 193us/step - loss: 0.0146 - acc: 0.9958 - val_loss: 0.0264 - val_acc: 1.0000
# Epoch 36/55
# 475/475 [==============================] - 0s 193us/step - loss: 0.0134 - acc: 0.9958 - val_loss: 0.0045 - val_acc: 1.0000
# Epoch 37/55
# 475/475 [==============================] - 0s 206us/step - loss: 0.0091 - acc: 1.0000 - val_loss: 0.0055 - val_acc: 1.0000
# Epoch 38/55
# 475/475 [==============================] - 0s 160us/step - loss: 0.0089 - acc: 1.0000 - val_loss: 0.0042 - val_acc: 1.0000
# Epoch 39/55
# 475/475 [==============================] - 0s 139us/step - loss: 0.0065 - acc: 1.0000 - val_loss: 0.0039 - val_acc: 1.0000
# Epoch 40/55
# 475/475 [==============================] - 0s 139us/step - loss: 0.0059 - acc: 1.0000 - val_loss: 0.0078 - val_acc: 1.0000
# Epoch 41/55
# 475/475 [==============================] - 0s 149us/step - loss: 0.0080 - acc: 1.0000 - val_loss: 0.0024 - val_acc: 1.0000
# Epoch 42/55
# 475/475 [==============================] - 0s 168us/step - loss: 0.0041 - acc: 1.0000 - val_loss: 0.0027 - val_acc: 1.0000
# Epoch 43/55
# 475/475 [==============================] - 0s 155us/step - loss: 0.0037 - acc: 1.0000 - val_loss: 0.0021 - val_acc: 1.0000
# Epoch 44/55
# 475/475 [==============================] - 0s 168us/step - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0018 - val_acc: 1.0000
# Epoch 45/55
# 475/475 [==============================] - 0s 172us/step - loss: 0.0024 - acc: 1.0000 - val_loss: 0.0019 - val_acc: 1.0000
# Epoch 46/55
# 475/475 [==============================] - 0s 185us/step - loss: 0.0022 - acc: 1.0000 - val_loss: 0.0013 - val_acc: 1.0000
# Epoch 47/55
# 475/475 [==============================] - 0s 216us/step - loss: 0.0027 - acc: 1.0000 - val_loss: 0.0365 - val_acc: 1.0000
# Epoch 48/55
# 475/475 [==============================] - 0s 195us/step - loss: 0.0067 - acc: 1.0000 - val_loss: 0.0011 - val_acc: 1.0000
# Epoch 49/55
# 475/475 [==============================] - 0s 162us/step - loss: 0.0015 - acc: 1.0000 - val_loss: 0.0011 - val_acc: 1.0000
# Epoch 50/55
# 475/475 [==============================] - 0s 141us/step - loss: 0.0013 - acc: 1.0000 - val_loss: 0.0011 - val_acc: 1.0000
# Epoch 51/55
# 475/475 [==============================] - 0s 155us/step - loss: 0.0011 - acc: 1.0000 - val_loss: 9.5830e-04 - val_acc: 1.0000
# Epoch 52/55
# 475/475 [==============================] - 0s 174us/step - loss: 0.0010 - acc: 1.0000 - val_loss: 0.0010 - val_acc: 1.0000
# Epoch 53/55
# 475/475 [==============================] - 0s 187us/step - loss: 9.8158e-04 - acc: 1.0000 - val_loss: 8.0907e-04 - val_acc: 1.0000
# Epoch 54/55
# 475/475 [==============================] - 0s 199us/step - loss: 7.7685e-04 - acc: 1.0000 - val_loss: 6.9811e-04 - val_acc: 1.0000
# Epoch 55/55
# 475/475 [==============================] - 0s 202us/step - loss: 7.0292e-04 - acc: 1.0000 - val_loss: 6.2315e-04 - val_acc: 1.0000

# %%
#generate the report for the training process
def training_report(history):
    #get the data from the model history file 
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    #set our epochs
    epochs = range(1, len(acc) + 1)

    #plot the accuracy 
    plt.plot(epochs, acc, 'bo', label='Training acc')
    plt.plot(epochs, val_acc, 'b', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()

    plt.figure()
    
    #plot the loss
    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

    plt.show()

    #display the max values we attained
    print('Validation Accuracy: ', val_acc[np.argmax(val_acc)] * 100)
    print('Training Accuracy: ', acc[np.argmax(acc)] * 100)

# %%
training_report(history)
# Out:
# Validation Accuracy:  100.0
# Training Accuracy:  100.0

# %%
#test the model on our set aside testing data
def test_model(model, x_test):
    #gather the models prediction 
    
    #the model displays its prediction as a percent for every bucket at how confident the model is for 
    #each bucket. 
    
    #the highest percent in our case the the bucket the model has choosen
    preds = model.predict(x_test)
    
    y_pred = []
    
    #for ever row in the prediction list
    #grab the max value and append that index to the y_pred
    for row in preds:
        y_pred.append(np.argmax(row))
    
    #convert the list to a numpy array
    return np.asarray(y_pred)

# %%
#test the model against our test data and store the predictions in y_pred
y_pred = test_model(model, x_test)

# %%
#create the confusion matrix
def test_confusion_matrix(y_pred,y_test):
    print(confusion_matrix(y_test, y_pred))

# %%
#create the classification report
def test_classification_report(y_pred,y_test):
    print(skm.classification_report(y_test, y_pred))

# %%
test_confusion_matrix(y_pred,y_test)
# Out:
# [[2914    0    0    0    0]
#  [   0 1538    0    0    3]
#  [   0    0 2521    0    0]
#  [   0    4    0 1612    0]
#  [   0    0    1    0  907]]

# %%
#display the classification report on the predictions
test_classification_report(y_pred, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2914
#            1       1.00      1.00      1.00      1541
#            2       1.00      1.00      1.00      2521
#            3       1.00      1.00      1.00      1616
#            4       1.00      1.00      1.00       908
#
#     accuracy                           1.00      9500
#    macro avg       1.00      1.00      1.00      9500
# weighted avg       1.00      1.00      1.00      9500

# %%
#drop first n rows
def drop_first_n_rows(df, n):
    return df.iloc[n:]

# %%
#drop frist N rows in data
#WHERE N = #OF TRAIN DATA
data = drop_first_n_rows(data, 500)

# %%
#convert the prediction number to bucket number
def convert_to_bucket(Y):
    #the prediction number is the index of the array 1,2,3,4,5 
    #just add 1 to index to correct the bucket number
    
    #for every index in y
    for row in range(0, len(Y)):
        #replace the value at the index with value + 1
        Y[row] = Y[row] + 1
        
    #return Y
    return Y

# %%
#convert pred
pred = convert_to_bucket(y_pred)

#convert test
test = convert_to_bucket(y_test)

# %%
#convert our n x 1 numpy array to a pandas df
pdpred = pd.DataFrame(pred)

# %%
#add the pred list to the original dataframe

data['pred'] = pdpred.values

# %%
#drop all the useless data

data = data.drop(['subSpecialtyCd', 'fillerOrderStatusCd', 'locationName'], axis =1)

# %%
#reindex the columns of the data
data = data.reindex(columns=['concat', 'BUCKETNUM', 'pred'])

# %%
#display the data
data.head(60)
# Out:
#                                   concat  BUCKETNUM  pred
# 9757  *gip f incyte diagnostics bellevue          2     2
# 7598   *gyp f incyte diagnostics spokane          1     1
# 714     *op f incyte diagnostics spokane          3     3
# 1624   *gip c incyte diagnostics spokane          5     5
# 9601   *gyp f incyte diagnostics spokane          1     1
# 9830   *ns f incyte diagnostics bellevue          2     2
# 571    *gyp f incyte diagnostics spokane          1     1
# 8603   *gyp f incyte diagnostics spokane          1     1
# 6703   *gyp f incyte diagnostics spokane          1     1
# 1391    *dp f incyte diagnostics spokane          3     3
# 8984    *ns a incyte diagnostics spokane          5     5
# 7245  *gyp f incyte diagnostics bellevue          4     4
# 1188   *gip f incyte diagnostics spokane          3     3
# 6422    *dp s incyte diagnostics spokane          5     5
# 3884   *ns f incyte diagnostics bellevue          2     2
# 6261   *gyp f incyte diagnostics spokane          1     1
# 4897  *gyp f incyte diagnostics bellevue          4     4
# 2964   *dp f incyte diagnostics bellevue          2     2
# 9558    *op a incyte diagnostics spokane          5     5
# 3820    *dp f incyte diagnostics spokane          3     3
# 6918   *gp f incyte diagnostics bellevue          2     2
# 1850    *gp f incyte diagnostics spokane          3     3
# 1206    *dp f incyte diagnostics spokane          3     3
# 3867   *gip f incyte diagnostics spokane          3     3
# 5151  *gyp f incyte diagnostics bellevue          4     4
# 9869   *gyp f incyte diagnostics spokane          1     1
# 980     *op f incyte diagnostics spokane          3     3
# 4013    *ns i incyte diagnostics spokane          5     5
# 6982   *gip f incyte diagnostics spokane          3     3
# 4435   *gyp f incyte diagnostics spokane          1     1
# 8618   *gyp f incyte diagnostics spokane          1     1
# 9237   *gyp f incyte diagnostics spokane          1     1
# 6281   *gyp f incyte diagnostics spokane          1     1
# 9921   *gyp f incyte diagnostics spokane          1     1
# 7835   *gp f incyte diagnostics bellevue          2     2
# 7361    *dp f incyte diagnostics spokane          3     3
# 9513    *ns f incyte diagnostics spokane          3     3
# 400   *gyp f incyte diagnostics bellevue          4     4
# 3817   *ns f incyte diagnostics bellevue          2     2
# 1960   *gip f incyte diagnostics spokane          3     3
# 6662  *gyp f incyte diagnostics bellevue          4     4
# 4039  *gyp f incyte diagnostics bellevue          4     4
# 7829   *gyp f incyte diagnostics spokane          1     1
# 9725    *dp f incyte diagnostics spokane          3     3
# 9232    *dp f incyte diagnostics spokane          3     3
# 3558    *dp c incyte diagnostics spokane          5     5
# 8264    *op f incyte diagnostics spokane          3     3
# 8559    *gp f incyte diagnostics spokane          3     3
# 1703    *ns t incyte diagnostics spokane          5     5
# 662     *gp f incyte diagnostics spokane          3     3
# 5476   *gp f incyte diagnostics bellevue          2     2
# 6898   *gyp f incyte diagnostics spokane          1     1
# 8051   *gyp f incyte diagnostics spokane          1     1
# 8319    *ns i incyte diagnostics spokane          5     5
# 1028   *gp f incyte diagnostics bellevue          2     2
# 9971   *gyp f incyte diagnostics spokane          1     1
# 7992   *gyp f incyte diagnostics spokane          1     1
# 4446   *gyp f incyte diagnostics spokane          1     1
# 6907  *gyp f incyte diagnostics bellevue          4     4
# 5069  *gyp f incyte diagnostics bellevue          4     4
